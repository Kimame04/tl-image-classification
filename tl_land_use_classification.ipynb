# %% [markdown]
# <a href="https://colab.research.google.com/github/Kimame04/tl-land-use-classification/blob/master/tl_land_use_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Land Use Classification via Transfer Learning
#
# This project aims to be able to conduct image classification using existing pre-trainded models. We will evaluate the effectiveness of some popular deep neural networks on a land usage classification problem.

# %%
import numpy as np
import os
import io
import PIL
from PIL import Image
import tensorflow as tf
import pathlib
import matplotlib.pyplot as plt
import folium
import ee
from folium import plugins

# %% [markdown]
# ## Generating the Google Maps layer

# %%
basemaps = {
    'Google Maps': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=m&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Maps',
        overlay = True,
        control = True
    ),
    'Google Satellite': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=s&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Satellite',
        overlay = True,
        control = True
    ),
    'Google Terrain': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=p&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Terrain',
        overlay = True,
        control = True
    ),
    'Google Satellite Hybrid': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=y&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Satellite',
        overlay = True,
        control = True
    ),
    'Esri Satellite': folium.TileLayer(
        tiles = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
        attr = 'Esri',
        name = 'Esri Satellite',
        overlay = True,
        control = True
    )
}

# %%
def add_ee_layer(self, ee_image_object, vis_params, name):
  map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
  folium.raster_layers.TileLayer(
      tiles=map_id_dict['tile_fetcher'].url_format,
      attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
      name=name,
      overlay=True,
      control=True
  ).add_to(self)

folium.Map.add_ee_layer = add_ee_layer

first = (ee.ImageCollection('COPERNICUS/S2_SR')
         .filterBounds(ee.Geometry.Point(-70.48, 43.3631))
         .filterDate('2019-01-01', '2019-12-31')
         .sort('CLOUDY_PIXEL_PERCENTAGE')
         .first())

map = folium.Map(location=[1.38281, 103.81025], zoom_start=12)

# Add custom basemaps
basemaps['Google Maps'].add_to(map)
basemaps['Google Satellite'].add_to(map)

# Add fullscreen button
plugins.Fullscreen().add_to(map)

# Display the map.
display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_7d45fd266870465da237f84a6c1b1f31%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7d45fd266870465da237f84a6c1b1f31%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_7d45fd266870465da237f84a6c1b1f31%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_7d45fd266870465da237f84a6c1b1f31%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B1.38281%2C%20103.81025%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2012%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20 ...

# %%
ee.Authenticate()
ee.Initialize()
# Out:
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://accounts.google.com/o/oauth2/auth?client_id=517222506229-vsmmajv00ul0bs7p89v5m89qs8eb9359.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fearthengine+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&response_type=code&code_challenge=YJv3172bbta-rorLeTwD8Em7CAy8S-XFTm1ixXCsXsU&code_challenge_method=S256
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/1AX4XfWj4YFtSuZeMIvAyrmRtPaquXelFSPatfVrtPVGFwTWB9uT6bsKkQnM
#
# Successfully saved authorization token.

# %%
map.save('sg.html')

# %% [markdown]
# ## Dataset
#
# http://weegee.vision.ucmerced.edu/datasets/landuse.html

# %% [markdown]
# ### Retrieving dataset

# %%
# !git clone https://github.com/Kimame04/tl-land-use-classification.git
# Out:
# fatal: destination path 'tl-land-use-classification' already exists and is not an empty directory.

# %%
# !cd tl-land-use-classification/

# %%
current_path = os.getcwd()
for root, dirs, files in os.walk(current_path, topdown=False):
    for name in files:
        print(os.path.join(root, name))
        if os.path.splitext(os.path.join(root, name))[1].lower() == ".tif":
            if os.path.isfile(os.path.splitext(os.path.join(root, name))[0] + ".jpg"):
                print("A jpeg file already exists")
            else:
                outputfile = os.path.splitext(os.path.join(root, name))[0] + ".jpg"
                im = Image.open(os.path.join(root, name))
                im.thumbnail(im.size)
                im.save(outputfile, "JPEG", quality=100)
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse67.jpg
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse09.jpg
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse65.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse66.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse41.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse87.jpg
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse56.jpg
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse06.jpg
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse47.jpg
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse35.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse51.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse31.jpg
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse31.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse58.jpg
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse97.jpg
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse25.jpg
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse57.jpg
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse55.jpg
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse68.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse85.jpg
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse82.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse10.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse86.jpg
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse03.jpg
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse51.jpg
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse30.jpg
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse83.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse47.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse89.jpg
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse43.jpg
# /content/tl-land-use-classification/dataset/Images/golfcourse/golfcourse61.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral69.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral43.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral44.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral46.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral80.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral57.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral26.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral59.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral63.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral98.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral15.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral06.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral64.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral28.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral41.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral10.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral66.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral74.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral44.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral95.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral10.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral35.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral34.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral01.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral40.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral77.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral33.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral00.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral11.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral13.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral91.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral02.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral48.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral32.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral67.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral70.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral25.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral16.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral15.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral52.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral88.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral81.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral08.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral47.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral21.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral51.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral14.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral60.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral52.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral62.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral86.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral30.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral56.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral59.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral45.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral57.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral66.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral74.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral95.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral36.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral49.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral12.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral26.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral34.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral93.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral22.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral79.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral58.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral76.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral68.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral18.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral86.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral38.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral31.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral42.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral07.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral29.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral46.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral35.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral36.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral30.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral58.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral07.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral37.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral23.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral05.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral83.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral97.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral68.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral63.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral04.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral51.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral12.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral92.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral19.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral16.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral90.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral41.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral24.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral39.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral09.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral81.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral71.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral65.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral55.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral62.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral43.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral65.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral98.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral76.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral73.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral72.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral93.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral90.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral53.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral54.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral40.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral89.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral88.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral14.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral82.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral71.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral02.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral03.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral83.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral38.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral42.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral24.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral69.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral20.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral56.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral92.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral23.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral06.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral28.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral97.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral17.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral96.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral13.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral84.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral08.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral87.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral78.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral94.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral99.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral01.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral04.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral61.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral64.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral48.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral27.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral20.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral50.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral70.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral67.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral91.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral75.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral45.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral25.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral00.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral03.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral05.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral96.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral27.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral89.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral47.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral53.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral18.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral85.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral11.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral21.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral55.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral78.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral72.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral80.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral33.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral49.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral39.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral61.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral32.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral82.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral87.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral75.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral60.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral77.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral79.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral29.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral22.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral09.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral85.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral84.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral73.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral94.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral31.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral99.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral19.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral54.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral50.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral17.jpg
# /content/tl-land-use-classification/dataset/Images/chaparral/chaparral37.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot77.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot84.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot02.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot93.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot52.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot42.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot44.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot71.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot57.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot12.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot78.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot95.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot60.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot77.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot61.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot07.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot19.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot25.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot27.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot79.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot58.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot54.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot17.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot18.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot76.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot26.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot35.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot82.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot48.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot80.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot69.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot63.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot68.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot32.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot79.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot03.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot38.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot04.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot14.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot48.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot88.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot10.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot02.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot27.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/sg-parkinglot-3.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot33.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot91.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot99.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot36.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot54.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot56.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot94.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot11.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot83.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot20.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/sg-parkinglot-1.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot59.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot73.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot17.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot97.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/sg-parkinglot-1.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot69.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot64.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot06.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot22.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot66.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot04.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot07.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot47.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot58.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot41.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot15.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot42.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot39.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot57.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot81.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot45.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot00.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot86.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot97.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot78.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot67.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot61.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot81.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot91.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot98.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot72.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot82.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/sg-parkinglot-3.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot29.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot49.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot66.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/sg-parkinglot-4.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot47.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot68.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot80.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot60.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot83.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot98.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot87.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot46.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot37.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot43.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot96.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot05.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot03.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot63.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot53.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot13.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot10.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot67.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot71.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot92.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot24.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot23.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot74.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot36.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot09.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot16.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot01.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot53.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot23.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/sg-parkinglot-2.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot49.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot50.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot75.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot70.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot76.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot93.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot31.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot20.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/sg-parkinglot-4.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot22.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot44.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot32.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot87.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot51.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot90.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot13.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot65.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot94.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot86.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot21.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot19.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot72.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot34.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot31.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot84.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot95.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot62.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot24.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot75.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot29.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot92.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot74.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot34.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot26.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot88.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot40.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot37.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot33.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot85.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot11.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot38.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot30.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot41.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot08.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot39.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot65.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot30.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot50.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot89.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot21.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot89.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot56.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot00.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot28.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot06.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot35.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot46.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot51.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot14.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot62.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot18.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/sg-parkinglot-2.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot70.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot73.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot01.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot15.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot85.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot96.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot55.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot99.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot40.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot55.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot52.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot12.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot16.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot25.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot59.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot90.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot64.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot08.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot09.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot05.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot28.jpg
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot45.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/parkinglot/parkinglot43.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection18.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection98.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection27.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection57.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection48.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection18.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection05.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection51.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection30.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection12.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection39.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection87.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection84.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection72.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection37.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection10.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection55.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/sg-intersection-2.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection42.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection88.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection73.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection76.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection77.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection41.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection68.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection69.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection77.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection99.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection35.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection40.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection56.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection02.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection01.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection49.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection31.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection43.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection35.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection76.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection13.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection64.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection95.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection69.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection54.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection70.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection29.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection25.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection01.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection89.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection74.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection53.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection80.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection19.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection43.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection13.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection09.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection48.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection58.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection91.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection47.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection92.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection86.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection72.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection25.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection58.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection23.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection21.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection39.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection90.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection82.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection81.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection22.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection06.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection59.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection79.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection19.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection11.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection40.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection16.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/intersection/intersection14.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection44.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection15.jpg
# /content/tl-land-use-classification/dataset/Images/intersection/intersection89.tif
# ...
# /content/tl-land-use-classification/dataset/Images/beach/beach45.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach80.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach87.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach75.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach13.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach13.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach26.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach69.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach45.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach43.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach82.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach11.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach51.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach52.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach81.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach60.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach92.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach89.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach95.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach15.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach59.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach86.jpg
# /content/tl-land-use-classification/dataset/Images/beach/sg-beach-1.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach68.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach42.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach35.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach86.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach42.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach34.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach78.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach76.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach23.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach22.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach59.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach91.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach41.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach07.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach49.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach77.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach72.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach90.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach16.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach98.jpg
# /content/tl-land-use-classification/dataset/Images/beach/sg-beach-3.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach67.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach64.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach68.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach43.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach54.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach99.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach37.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach74.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach23.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach18.jpg
# /content/tl-land-use-classification/dataset/Images/beach/sg-beach-4.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach05.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach85.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach96.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach56.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach01.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach32.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach88.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach91.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach27.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach28.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach08.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach36.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach71.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach07.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach09.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach20.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach89.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach63.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach29.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach55.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach95.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach40.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach81.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach69.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach49.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach55.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach16.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach17.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach54.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach04.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach12.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/sg-beach-2.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach77.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach27.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach28.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach30.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach96.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach58.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach61.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach67.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach06.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach93.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach97.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach80.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach51.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach46.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach65.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach38.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach47.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach79.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach14.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach39.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach99.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach19.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach26.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach78.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach33.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach70.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach09.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach25.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach04.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach31.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach56.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach10.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach00.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach90.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach18.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach57.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach08.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach05.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach39.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach03.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach87.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach24.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach63.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach30.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach73.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach62.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach12.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach53.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach32.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach73.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach36.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach00.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach74.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach58.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach48.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach61.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach66.jpg
# /content/tl-land-use-classification/dataset/Images/beach/sg-beach-3.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach93.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach21.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach53.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach44.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach19.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach01.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach17.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach50.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach97.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach84.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach33.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach65.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach21.jpg
# /content/tl-land-use-classification/dataset/Images/beach/sg-beach-4.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach98.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach94.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach79.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach50.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach02.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach20.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach60.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach10.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach37.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach35.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach03.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach47.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach02.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach52.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach34.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach94.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach82.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach24.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach14.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach84.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach29.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach70.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach83.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach76.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach71.tif
# A jpeg file already exists
# /content/tl-land-use-classification/dataset/Images/beach/beach15.jpg
# /content/tl-land-use-classification/dataset/Images/beach/beach31.jpg
# /content/tl-land-use-classification/dataset/readme.txt.bak
# /content/tl-land-use-classification/dataset/readme.txt
# /content/tl-land-use-classification/image_classification_transfer_learning.ipynb
# /content/tl-land-use-classification/.gitignore
# /content/tl-land-use-classification/README.md
# /content/tl-land-use-classification/LICENSE
# /content/tl-land-use-classification/sg.html
# /content/sample_data/anscombe.json
# /content/sample_data/README.md
# /content/sample_data/california_housing_train.csv
# /content/sample_data/california_housing_test.csv
# /content/sample_data/mnist_train_small.csv
# /content/sample_data/mnist_test.csv

# %%
data_dir = 'tl-land-use-classification/dataset/Images'
batch_size = 32
img_height = 256
img_width = 256

train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  label_mode='categorical',
  batch_size=batch_size)

validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  label_mode='categorical',
  batch_size=batch_size)

class_names = train_dataset.class_names
# Out:
# Found 2156 files belonging to 21 classes.
# Using 1725 files for training.
# Found 2156 files belonging to 21 classes.
# Using 431 files for validation.

# %% [markdown]
# ### Data processing

# %%
val_batches = tf.data.experimental.cardinality(validation_dataset)
test_dataset = validation_dataset.take(val_batches // 5)
validation_dataset = validation_dataset.skip(val_batches // 5)

data_augmentation = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip('horizontal'),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
])

image_batch, label_batch = next(iter(train_dataset))

# %% [markdown]
# ### Creating the model

# %%
def createModel(base_model,shape):
  feature_batch = base_model(image_batch)

  base_model.trainable = False

  global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
  feature_batch_average = global_average_layer(feature_batch)


  inputs = tf.keras.Input(shape=shape)
  x = data_augmentation(inputs)
  x = base_model(x, training=False)
  x = global_average_layer(x)
  x = tf.keras.layers.Dropout(0.5)(x)
  outputs = tf.keras.layers.Dense(len(class_names),activation='softmax')(x)
  model = tf.keras.Model(inputs, outputs)

  base_learning_rate = 0.0001
  model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
  model.summary()
  return model

# %% [markdown]
# ### Fitting the model

# %%
initial_epochs = 5
checkpoint_path = "training/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1, 
    save_weights_only=True,
    save_freq=54)

# %%
resnet_model = createModel(tf.keras.applications.ResNet50(weights='imagenet',
                                            include_top=False),(256,256,3))

resnet_model.fit(train_dataset,
          epochs=initial_epochs,
          validation_data=validation_dataset,
          validation_freq=1,
          callbacks=[cp_callback])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# sequential (Sequential)      (None, 256, 256, 3)       0
# _________________________________________________________________
# resnet50 (Functional)        (None, None, None, 2048)  23587712
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 21)                43029
# =================================================================
# Total params: 23,630,741
# Trainable params: 43,029
# Non-trainable params: 23,587,712
# _________________________________________________________________
# Epoch 1/5
# 54/54 [==============================] - ETA: 0s - loss: 2.0095 - accuracy: 0.4371
# Epoch 00001: saving model to training/cp.ckpt
# 54/54 [==============================] - 310s 6s/step - loss: 2.0095 - accuracy: 0.4371 - val_loss: 0.7238 - val_accuracy: 0.7711
# Epoch 2/5
# 54/54 [==============================] - ETA: 0s - loss: 0.7461 - accuracy: 0.7490
# Epoch 00002: saving model to training/cp.ckpt
# 54/54 [==============================] - 309s 6s/step - loss: 0.7461 - accuracy: 0.7490 - val_loss: 0.4473 - val_accuracy: 0.8665
# Epoch 3/5
# 54/54 [==============================] - ETA: 0s - loss: 0.5060 - accuracy: 0.8406
# Epoch 00003: saving model to training/cp.ckpt
# 54/54 [==============================] - 309s 6s/step - loss: 0.5060 - accuracy: 0.8406 - val_loss: 0.3879 - val_accuracy: 0.8774
# Epoch 4/5
# 54/54 [==============================] - ETA: 0s - loss: 0.3801 - accuracy: 0.8771
# Epoch 00004: saving model to training/cp.ckpt
# 54/54 [==============================] - 310s 6s/step - loss: 0.3801 - accuracy: 0.8771 - val_loss: 0.3277 - val_accuracy: 0.8910
# Epoch 5/5
# 54/54 [==============================] - ETA: 0s - loss: 0.3403 - accuracy: 0.8991
# Epoch 00005: saving model to training/cp.ckpt
# 54/54 [==============================] - 312s 6s/step - loss: 0.3403 - accuracy: 0.8991 - val_loss: 0.2782 - val_accuracy: 0.9292

# %%
mobilenet_model = createModel(tf.keras.applications.MobileNetV2(include_top=False),(256,256,3))

mobilenet_model.fit(train_dataset,
          epochs=initial_epochs,
          validation_data=validation_dataset,
          validation_freq=1,
          callbacks=[cp_callback])
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# sequential (Sequential)      (None, 256, 256, 3)       0
# _________________________________________________________________
# mobilenetv2_1.00_224 (Functi (None, None, None, 1280)  2257984
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 1280)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1280)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 21)                26901
# =================================================================
# Total params: 2,284,885
# Trainable params: 26,901
# Non-trainable params: 2,257,984
# _________________________________________________________________
# Epoch 1/5
# 54/54 [==============================] - ETA: 0s - loss: 3.0099 - accuracy: 0.1612
# Epoch 00001: saving model to training/cp.ckpt
# 54/54 [==============================] - 89s 2s/step - loss: 3.0099 - accuracy: 0.1612 - val_loss: 2.1221 - val_accuracy: 0.3406
# Epoch 2/5
# 54/54 [==============================] - ETA: 0s - loss: 2.1533 - accuracy: 0.3252
# Epoch 00002: saving model to training/cp.ckpt
# 54/54 [==============================] - 86s 2s/step - loss: 2.1533 - accuracy: 0.3252 - val_loss: 1.7478 - val_accuracy: 0.4632
# Epoch 3/5
# 54/54 [==============================] - ETA: 0s - loss: 1.8088 - accuracy: 0.4116
# Epoch 00003: saving model to training/cp.ckpt
# 54/54 [==============================] - 85s 2s/step - loss: 1.8088 - accuracy: 0.4116 - val_loss: 1.5923 - val_accuracy: 0.5041
# Epoch 4/5
# 54/54 [==============================] - ETA: 0s - loss: 1.6172 - accuracy: 0.4765
# Epoch 00004: saving model to training/cp.ckpt
# 54/54 [==============================] - 85s 2s/step - loss: 1.6172 - accuracy: 0.4765 - val_loss: 1.5156 - val_accuracy: 0.5422
# Epoch 5/5
# 54/54 [==============================] - ETA: 0s - loss: 1.4785 - accuracy: 0.5217
# Epoch 00005: saving model to training/cp.ckpt
# 54/54 [==============================] - 86s 2s/step - loss: 1.4785 - accuracy: 0.5217 - val_loss: 1.3378 - val_accuracy: 0.5967

# %%
inceptionv3_model = createModel(tf.keras.applications.InceptionV3(include_top=False),(256,256,3))
inceptionv3_model.fit(train_dataset,
          epochs=initial_epochs,
          validation_data=validation_dataset,
          validation_freq=1,
          callbacks=[cp_callback])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# sequential (Sequential)      (None, 256, 256, 3)       0
# _________________________________________________________________
# inception_v3 (Functional)    (None, None, None, 2048)  21802784
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 2048)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 21)                43029
# =================================================================
# Total params: 21,845,813
# Trainable params: 43,029
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Epoch 1/5
# 54/54 [==============================] - ETA: 0s - loss: 40.9086 - accuracy: 0.1078
# Epoch 00001: saving model to training/cp.ckpt
# 54/54 [==============================] - 215s 4s/step - loss: 40.9086 - accuracy: 0.1078 - val_loss: 12.6292 - val_accuracy: 0.2589
# Epoch 2/5
# 54/54 [==============================] - ETA: 0s - loss: 29.9046 - accuracy: 0.1751
# Epoch 00002: saving model to training/cp.ckpt
# 54/54 [==============================] - 209s 4s/step - loss: 29.9046 - accuracy: 0.1751 - val_loss: 12.5708 - val_accuracy: 0.3134
# Epoch 3/5
# 54/54 [==============================] - ETA: 0s - loss: 23.9617 - accuracy: 0.2284
# Epoch 00003: saving model to training/cp.ckpt
# 54/54 [==============================] - 209s 4s/step - loss: 23.9617 - accuracy: 0.2284 - val_loss: 10.7670 - val_accuracy: 0.3433
# Epoch 4/5
# 54/54 [==============================] - ETA: 0s - loss: 20.5295 - accuracy: 0.2388
# Epoch 00004: saving model to training/cp.ckpt
# 54/54 [==============================] - 207s 4s/step - loss: 20.5295 - accuracy: 0.2388 - val_loss: 9.7756 - val_accuracy: 0.3433
# Epoch 5/5
# 54/54 [==============================] - ETA: 0s - loss: 18.4064 - accuracy: 0.2661
# Epoch 00005: saving model to training/cp.ckpt
# 54/54 [==============================] - 207s 4s/step - loss: 18.4064 - accuracy: 0.2661 - val_loss: 8.4548 - val_accuracy: 0.4060

# %%
vgg16_model = createModel(tf.keras.applications.VGG16(include_top=False),(256,256,3))
vgg16_model.fit(train_dataset,
          epochs=initial_epochs,
          validation_data=validation_dataset,
          validation_freq=1,
          callbacks=[cp_callback])
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# sequential (Sequential)      (None, 256, 256, 3)       0
# _________________________________________________________________
# vgg16 (Functional)           (None, None, None, 512)   14714688
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 21)                10773
# =================================================================
# Total params: 14,725,461
# Trainable params: 10,773
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/5
# 37/54 [===================>..........] - ETA: 7:02 - loss: 10.5958 - accuracy: 0.0912
# Epoch 00001: saving model to training/cp.ckpt
# 54/54 [==============================] - 1648s 30s/step - loss: 9.4849 - accuracy: 0.1270 - val_loss: 2.4993 - val_accuracy: 0.4360
# Epoch 2/5
# 37/54 [===================>..........] - ETA: 7:03 - loss: 5.3699 - accuracy: 0.2948
# Epoch 00002: saving model to training/cp.ckpt
# 54/54 [==============================] - 1635s 30s/step - loss: 4.9392 - accuracy: 0.3310 - val_loss: 1.2930 - val_accuracy: 0.6512
# Epoch 3/5
# 37/54 [===================>..........] - ETA: 7:06 - loss: 3.8527 - accuracy: 0.4367
# Epoch 00003: saving model to training/cp.ckpt
# 54/54 [==============================] - 1642s 30s/step - loss: 3.5680 - accuracy: 0.4580 - val_loss: 1.0433 - val_accuracy: 0.7411
# Epoch 4/5
# 37/54 [===================>..........] - ETA: 7:03 - loss: 2.4222 - accuracy: 0.5642
# Epoch 00004: saving model to training/cp.ckpt
# 54/54 [==============================] - 1625s 30s/step - loss: 2.4205 - accuracy: 0.5716 - val_loss: 0.8661 - val_accuracy: 0.7902
# Epoch 5/5
# 37/54 [===================>..........] - ETA: 7:05 - loss: 2.0295 - accuracy: 0.6123
# Epoch 00005: saving model to training/cp.ckpt
# 54/54 [==============================] - 1626s 30s/step - loss: 1.8919 - accuracy: 0.6325 - val_loss: 0.6322 - val_accuracy: 0.8065

# %%
efficientnet_model = createModel(tf.keras.applications.EfficientNetB0(include_top=False),(256,256,3))
efficientnet_model.fit(train_dataset,
          epochs=initial_epochs,
          validation_data=validation_dataset,
          validation_freq=1,
          callbacks=[cp_callback])
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16711680/16705208 [==============================] - 1s 0us/step
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# sequential (Sequential)      (None, 256, 256, 3)       0
# _________________________________________________________________
# efficientnetb0 (Functional)  (None, None, None, 1280)  4049571
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 1280)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1280)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 21)                26901
# =================================================================
# Total params: 4,076,472
# Trainable params: 26,901
# Non-trainable params: 4,049,571
# _________________________________________________________________
# Epoch 1/5
# 37/54 [===================>..........] - ETA: 1:26 - loss: 2.3682 - accuracy: 0.3269
# Epoch 00001: saving model to training/cp.ckpt
# 54/54 [==============================] - 379s 7s/step - loss: 2.0355 - accuracy: 0.4406 - val_loss: 1.0810 - val_accuracy: 0.8038
# Epoch 2/5
# 37/54 [===================>..........] - ETA: 1:30 - loss: 0.9527 - accuracy: 0.7855
# Epoch 00002: saving model to training/cp.ckpt
# 54/54 [==============================] - 348s 6s/step - loss: 0.8898 - accuracy: 0.7936 - val_loss: 0.6753 - val_accuracy: 0.8365
# Epoch 3/5
# 37/54 [===================>..........] - ETA: 1:34 - loss: 0.6262 - accuracy: 0.8547
# Epoch 00003: saving model to training/cp.ckpt
# 54/54 [==============================] - 358s 7s/step - loss: 0.5918 - accuracy: 0.8684 - val_loss: 0.5120 - val_accuracy: 0.8692
# Epoch 4/5
# 37/54 [===================>..........] - ETA: 1:34 - loss: 0.5001 - accuracy: 0.8894
# Epoch 00004: saving model to training/cp.ckpt
# 54/54 [==============================] - 357s 7s/step - loss: 0.4884 - accuracy: 0.8835 - val_loss: 0.4155 - val_accuracy: 0.8910
# Epoch 5/5
# 37/54 [===================>..........] - ETA: 1:34 - loss: 0.4121 - accuracy: 0.9096
# Epoch 00005: saving model to training/cp.ckpt
# 54/54 [==============================] - 357s 7s/step - loss: 0.3914 - accuracy: 0.9125 - val_loss: 0.3936 - val_accuracy: 0.8856

# %% [markdown]
# ### Saving the model

# %%
# !mkdir -p resnet_model
resnet_model.save('resnet_model')
# !zip -r /content/resnet_model.zip /content/resnet_model/

# %%
# !mkdir -p mobilenet_model
mobilenet_model.save('mobilenet_model')
# !zip -r /content/mobilenet_model.zip /content/mobilenet_model/
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# INFO:tensorflow:Assets written to: resnet_model/assets
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# INFO:tensorflow:Assets written to: mobilenet_model/assets
# INFO:tensorflow:Assets written to: inceptionv3_model/assets

# %%
# !mkdir -p inceptionv3_model
inceptionv3_model.save('inceptionv3_model')
# !zip -r /content/inceptionv3_model.zip /content/inceptionv3_model/
# Out:
#   adding: content/resnet_model/ (stored 0%)
#   adding: content/resnet_model/saved_model.pb (deflated 92%)
#   adding: content/resnet_model/variables/ (stored 0%)
#   adding: content/resnet_model/variables/variables.index (deflated 78%)
#   adding: content/resnet_model/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: content/resnet_model/assets/ (stored 0%)
#   adding: content/resnet_model/keras_metadata.pb (deflated 96%)
#   adding: content/mobilenet_model/ (stored 0%)
#   adding: content/mobilenet_model/saved_model.pb (deflated 92%)
#   adding: content/mobilenet_model/variables/ (stored 0%)
#   adding: content/mobilenet_model/variables/variables.index (deflated 75%)
#   adding: content/mobilenet_model/variables/variables.data-00000-of-00001 (deflated 8%)
#   adding: content/mobilenet_model/assets/ (stored 0%)
#   adding: content/mobilenet_model/keras_metadata.pb (deflated 96%)
#   adding: content/inceptionv3_model/ (stored 0%)
#   adding: content/inceptionv3_model/saved_model.pb (deflated 92%)
#   adding: content/inceptionv3_model/variables/ (stored 0%)
#   adding: content/inceptionv3_model/variables/variables.index (deflated 76%)
#   adding: content/inceptionv3_model/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: content/inceptionv3_model/assets/ (stored 0%)
#   adding: content/inceptionv3_model/keras_metadata.pb (deflated 96%)

# %%
# !mkdir -p vgg16_model
vgg16_model.save('vgg16_model')
# !zip -r /content/vgg16_model.zip /content/vgg16_model/
# Out:
# INFO:tensorflow:Assets written to: vgg16_model/assets
#   adding: content/vgg16_model/ (stored 0%)
#   adding: content/vgg16_model/assets/ (stored 0%)
#   adding: content/vgg16_model/keras_metadata.pb (deflated 96%)
#   adding: content/vgg16_model/variables/ (stored 0%)
#   adding: content/vgg16_model/variables/variables.index (deflated 64%)
#   adding: content/vgg16_model/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: content/vgg16_model/saved_model.pb (deflated 91%)

# %%
# !mkdir -p efficientnet_model
efficientnet_model.save('efficientnet_model')
# !zip -r /content/efficientnet_model.zip /content/efficientnet_model/
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# INFO:tensorflow:Assets written to: efficientnet_model/assets
#   adding: content/efficientnet_model/ (stored 0%)
#   adding: content/efficientnet_model/assets/ (stored 0%)
#   adding: content/efficientnet_model/keras_metadata.pb (deflated 96%)
#   adding: content/efficientnet_model/variables/ (stored 0%)
#   adding: content/efficientnet_model/variables/variables.index (deflated 73%)
#   adding: content/efficientnet_model/variables/variables.data-00000-of-00001 (deflated 8%)
#   adding: content/efficientnet_model/saved_model.pb (deflated 91%)

# %% [markdown]
# ## Loading the saved model

# %% [markdown]
# ### Testing the model with unseen data

# %%
def testModel(model):
  loss, acc = model.evaluate(test_dataset, verbose=1)
  print('Restored model, accuracy: {:5.2f}%'.format(100 * acc))

# %%
resnet_dir = 'tl-land-use-classification/resnet_model'
resnet_model = tf.keras.models.load_model(resnet_dir)
resnet_model.summary()
testModel(resnet_model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c17963aa3fde> in <module>()
#       1 resnet_dir = 'tl-land-use-classification/resnet_model'
# ----> 2 resnet_model = tf.keras.models.load_model(resnet_dir)
#       3 resnet_model.summary()
#       4 testModel(resnet_model)
#
# NameError: name 'tf' is not defined

# %%
mobilenet_dir = 'tl-land-use-classification/mobilenet_model'
mobilenet_model = tf.keras.models.load_model(mobilenet_dir)
mobilenet_model.summary()
testModel(mobilenet_model)
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# sequential (Sequential)      (None, 256, 256, 3)       0
# _________________________________________________________________
# mobilenetv2_1.00_224 (Functi (None, None, None, 1280)  2257984
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 1280)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1280)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 21)                26901
# =================================================================
# Total params: 2,284,885
# Trainable params: 26,901
# Non-trainable params: 2,257,984
# _________________________________________________________________
# 2/2 [==============================] - 19s 3s/step - loss: 1.5874 - accuracy: 0.4844
# Restored model, accuracy: 48.44%

# %%
inceptionv3_dir = 'tl-land-use-classification/inceptionv3_model'
inceptionv3_model = tf.keras.models.load_model(inceptionv3_dir)
inceptionv3_model.summary()
testModel(inceptionv3_model)
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# sequential (Sequential)      (None, 256, 256, 3)       0
# _________________________________________________________________
# inception_v3 (Functional)    (None, None, None, 2048)  21802784
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 2048)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 21)                43029
# =================================================================
# Total params: 21,845,813
# Trainable params: 43,029
# Non-trainable params: 21,802,784
# _________________________________________________________________
# WARNING:tensorflow:5 out of the last 67 calls to <function Model.make_test_function.<locals>.test_function at 0x7f696a7d4dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 28s 7s/step - loss: 6.7579 - accuracy: 0.3906
# Restored model, accuracy: 39.06%

# %% [markdown]
# ### Converting to TensorFlow Lite

# %%
converter = tf.lite.TFLiteConverter.from_saved_model(resnet_dir)
tflite_model = converter.convert()

with open('model.tflite', 'wb') as f:
  f.write(tflite_model)
